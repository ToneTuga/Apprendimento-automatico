# %% [markdown]
# # Exercizes on clustering

# %% [markdown]
# Here you can find a program to read a data file in csv format.
#
# The data file has the following heading:
#     number of samples, number of features
#     list of the names of the features (separated by comma)
#
# The remaining lines contain an example per row.
# For each row there is a list of real numbers (commas separated) which are the feature values.

# %%
import csv
from os.path import join

import numpy as np


# this function reads the data file, loads the configuration attributes specifiefd in the heading
# (numer of examples and features), the list of feature names
# and loads the data in a matrix named data
def load_data(file_path, file_name):
    with open(join(file_path, file_name)) as csv_file:
        data_file = csv.reader(csv_file, delimiter=",")
        temp1 = next(data_file)
        n_samples = int(temp1[0])
        print("n_samples=")
        print(n_samples)
        n_features = int(temp1[1])
        temp2 = next(data_file)
        feature_names = np.array(temp2[:n_features])

        data_list = [iter for iter in data_file]

        data = np.asarray(data_list, dtype=np.float64)

    return (data, feature_names, n_samples, n_features)


# The main program reads the input file containing the dataset
# file_path is the file path where the file with the data to be read are located
# we assume the file contains an example per line
# each example is a list of real values separated by a comma (csv format)
# The first line of the file contains the heading with:
# N_samples,n_features,
# The second line contains the feature names separated by a comma

file_path = "./"
# all the three datasets contain data points on (x,y)
file_name1 = "3-clusters.csv"
file_name2 = "dataset-DBSCAN.csv"
file_name3 = "CURE-complete.csv"
data1, feature_names1, n_samples1, n_features1 = load_data(file_path, file_name1)
data2, feature_names2, n_samples2, n_features2 = load_data(file_path, file_name2)
data3, feature_names3, n_samples3, n_features3 = load_data(file_path, file_name3)
print("dataset n. 1: n samples, n features")
print(n_samples1, n_features1)
print("dataset n. 2: n samples, n features")
print(n_samples2, n_features2)
print("dataset n. 3: n samples, n features")
print(n_samples3, n_features3)
# Out:
# n_samples=
# 150
# n_samples=
# 6118
# n_samples=
# 86558
# dataset n. 1: n samples, n features
# 150 2
# dataset n. 2: n samples, n features
# 6118 2
# dataset n. 3: n samples, n features
# 86558 2

# %% [markdown]
# The following program plots the dataset n.1

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 8))

ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n. 1 of data points")

ax.set_xlabel(feature_names1[0])
ax.set_ylabel(feature_names1[1])

# plot the dataset
plt.plot(data1[:, 0], data1[:, 1], ".", markersize=1)

plt.show()

# %% [markdown]
# The following is the program for plotting the dataset n.2

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20, 10))

ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n. 2 of data points")

ax.set_xlabel(feature_names2[0])
ax.set_ylabel(feature_names2[1])

# plot the dataset
plt.plot(data2[:, 0], data2[:, 1], ".", markersize=2)

plt.show()

# %% [markdown]
# The following is the program for plotting the dataset n.3

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 8))

ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Dataset n. 3 of data points")

ax.set_xlabel(feature_names3[0])
ax.set_ylabel(feature_names3[1])

# plot the dataset
plt.plot(data3[:, 0], data3[:, 1], ".", markersize=1.2, markeredgecolor="blue")

plt.show()

# %% [markdown]
# ## In the following program we cluster the dataset n.1 with K-means.
# From the plot of dataset n.1 we see 3 separated clusters. Thus k=3.

# %%
import csv
from os.path import join

import numpy as np


def load_data(file_path, file_name):
    with open(join(file_path, file_name)) as csv_file:
        data_file = csv.reader(csv_file, delimiter=",")
        temp1 = next(data_file)
        n_samples = int(temp1[0])
        n_features = int(temp1[1])
        temp2 = next(data_file)
        feature_names = np.array(temp2[:n_features])

        data_list = [iter for iter in data_file]

        data = np.asarray(data_list, dtype=np.float64)

    return (data, feature_names, n_samples, n_features)


# The main program reads the input file containing the dataset
# file_path is the file path where the file with the data to be read are located
# we assume the file contains an example per line
# each example is a list of real values separated by a comma (csv format)
# The first line of the file contains the heading with:
# N_samples,n_features,
# The second line contains the feature names separated by a comma

file_path = "./"
# all the three datasets contain data points on (x,y)
file_name1 = "3-clusters.csv"

data1, feature_names1, n_samples1, n_features1 = load_data(file_path, file_name1)

from sklearn.cluster import KMeans

np.random.seed(5)

k = 3
kmeans1 = KMeans(n_clusters=k, random_state=0).fit(data1)

for i in range(n_samples1):
    print(
        "Example n." + str(i) + "=(" + str(data1[i, 0]) + "," + str(data1[i, 1]) + ")"
    )
    print("in cluster n." + str(kmeans1.labels_[i]))
# Out:
# Example n.0=(10.0,10.0)
# in cluster n.1
# Example n.1=(11.0,11.0)
# in cluster n.1
# Example n.2=(12.0,12.0)
# in cluster n.1
# Example n.3=(13.0,13.0)
# in cluster n.1
# Example n.4=(14.0,14.0)
# in cluster n.1
# Example n.5=(15.0,15.0)
# in cluster n.1
# Example n.6=(16.0,16.0)
# in cluster n.1
# Example n.7=(17.0,17.0)
# in cluster n.1
# Example n.8=(18.0,18.0)
# in cluster n.1
# Example n.9=(19.0,19.0)
# in cluster n.1
# Example n.10=(20.0,20.0)
# in cluster n.1
# Example n.11=(21.0,21.0)
# in cluster n.1
# Example n.12=(22.0,22.0)
# in cluster n.1
# Example n.13=(23.0,23.0)
# in cluster n.1
# Example n.14=(24.0,24.0)
# in cluster n.1
# Example n.15=(25.0,25.0)
# in cluster n.1
# Example n.16=(26.0,26.0)
# in cluster n.1
# Example n.17=(27.0,27.0)
# in cluster n.1
# Example n.18=(28.0,28.0)
# in cluster n.1
# Example n.19=(29.0,29.0)
# in cluster n.1
# Example n.20=(30.0,30.0)
# in cluster n.1
# Example n.21=(31.0,31.0)
# in cluster n.1
# Example n.22=(32.0,32.0)
# in cluster n.1
# Example n.23=(33.0,33.0)
# in cluster n.1
# Example n.24=(34.0,34.0)
# in cluster n.1
# Example n.25=(35.0,35.0)
# in cluster n.1
# Example n.26=(36.0,36.0)
# in cluster n.1
# Example n.27=(37.0,37.0)
# in cluster n.1
# Example n.28=(38.0,38.0)
# in cluster n.1
# Example n.29=(39.0,39.0)
# in cluster n.1
# Example n.30=(40.0,40.0)
# in cluster n.1
# Example n.31=(41.0,41.0)
# in cluster n.1
# Example n.32=(42.0,42.0)
# in cluster n.1
# Example n.33=(43.0,43.0)
# in cluster n.1
# Example n.34=(44.0,44.0)
# in cluster n.1
# Example n.35=(45.0,45.0)
# in cluster n.1
# Example n.36=(46.0,46.0)
# in cluster n.1
# Example n.37=(47.0,47.0)
# in cluster n.1
# Example n.38=(48.0,48.0)
# in cluster n.1
# Example n.39=(49.0,49.0)
# in cluster n.1
# Example n.40=(50.0,50.0)
# in cluster n.1
# Example n.41=(51.0,51.0)
# in cluster n.1
# Example n.42=(52.0,52.0)
# in cluster n.1
# Example n.43=(53.0,53.0)
# in cluster n.1
# Example n.44=(54.0,54.0)
# in cluster n.1
# Example n.45=(55.0,55.0)
# in cluster n.1
# Example n.46=(56.0,56.0)
# in cluster n.1
# Example n.47=(57.0,57.0)
# in cluster n.1
# Example n.48=(58.0,58.0)
# in cluster n.1
# Example n.49=(80.0,80.0)
# in cluster n.0
# Example n.50=(81.0,81.0)
# in cluster n.0
# Example n.51=(82.0,82.0)
# in cluster n.0
# Example n.52=(83.0,83.0)
# in cluster n.0
# Example n.53=(84.0,84.0)
# in cluster n.0
# Example n.54=(85.0,85.0)
# in cluster n.0
# Example n.55=(86.0,86.0)
# in cluster n.0
# Example n.56=(87.0,87.0)
# in cluster n.0
# Example n.57=(88.0,88.0)
# in cluster n.0
# Example n.58=(89.0,89.0)
# in cluster n.0
# Example n.59=(90.0,90.0)
# in cluster n.0
# Example n.60=(91.0,91.0)
# in cluster n.0
# Example n.61=(92.0,92.0)
# in cluster n.0
# Example n.62=(93.0,93.0)
# in cluster n.0
# Example n.63=(94.0,94.0)
# in cluster n.0
# Example n.64=(95.0,95.0)
# in cluster n.0
# Example n.65=(96.0,96.0)
# in cluster n.0
# Example n.66=(97.0,97.0)
# in cluster n.0
# Example n.67=(98.0,98.0)
# in cluster n.0
# Example n.68=(99.0,99.0)
# in cluster n.0
# Example n.69=(100.0,100.0)
# in cluster n.0
# Example n.70=(101.0,101.0)
# in cluster n.0
# Example n.71=(102.0,102.0)
# in cluster n.0
# Example n.72=(103.0,103.0)
# in cluster n.0
# Example n.73=(104.0,104.0)
# in cluster n.0
# Example n.74=(105.0,105.0)
# in cluster n.0
# Example n.75=(106.0,106.0)
# in cluster n.0
# Example n.76=(107.0,107.0)
# in cluster n.0
# Example n.77=(108.0,108.0)
# in cluster n.0
# Example n.78=(109.0,109.0)
# in cluster n.0
# Example n.79=(110.0,110.0)
# in cluster n.0
# Example n.80=(111.0,111.0)
# in cluster n.0
# Example n.81=(112.0,112.0)
# in cluster n.0
# Example n.82=(113.0,113.0)
# in cluster n.0
# Example n.83=(114.0,114.0)
# in cluster n.0
# Example n.84=(115.0,115.0)
# in cluster n.0
# Example n.85=(116.0,116.0)
# in cluster n.0
# Example n.86=(117.0,117.0)
# in cluster n.0
# Example n.87=(118.0,118.0)
# in cluster n.0
# Example n.88=(119.0,119.0)
# in cluster n.0
# Example n.89=(120.0,120.0)
# in cluster n.0
# Example n.90=(121.0,121.0)
# in cluster n.0
# Example n.91=(122.0,122.0)
# in cluster n.0
# Example n.92=(123.0,123.0)
# in cluster n.0
# Example n.93=(124.0,124.0)
# in cluster n.0
# Example n.94=(125.0,125.0)
# in cluster n.0
# Example n.95=(126.0,126.0)
# in cluster n.0
# Example n.96=(127.0,127.0)
# in cluster n.0
# Example n.97=(128.0,128.0)
# in cluster n.0
# Example n.98=(129.0,129.0)
# in cluster n.0
# Example n.99=(120.0,10.0)
# in cluster n.2
# Example n.100=(121.0,11.0)
# in cluster n.2
# Example n.101=(122.0,12.0)
# in cluster n.2
# Example n.102=(123.0,13.0)
# in cluster n.2
# Example n.103=(124.0,14.0)
# in cluster n.2
# Example n.104=(125.0,15.0)
# in cluster n.2
# Example n.105=(126.0,16.0)
# in cluster n.2
# Example n.106=(127.0,17.0)
# in cluster n.2
# Example n.107=(128.0,18.0)
# in cluster n.2
# Example n.108=(129.0,19.0)
# in cluster n.2
# Example n.109=(130.0,20.0)
# in cluster n.2
# Example n.110=(131.0,21.0)
# in cluster n.2
# Example n.111=(132.0,22.0)
# in cluster n.2
# Example n.112=(133.0,23.0)
# in cluster n.2
# Example n.113=(134.0,24.0)
# in cluster n.2
# Example n.114=(135.0,25.0)
# in cluster n.2
# Example n.115=(136.0,26.0)
# in cluster n.2
# Example n.116=(137.0,27.0)
# in cluster n.2
# Example n.117=(138.0,28.0)
# in cluster n.2
# Example n.118=(139.0,29.0)
# in cluster n.2
# Example n.119=(140.0,30.0)
# in cluster n.2
# Example n.120=(141.0,31.0)
# in cluster n.2
# Example n.121=(142.0,32.0)
# in cluster n.2
# Example n.122=(143.0,33.0)
# in cluster n.2
# Example n.123=(144.0,34.0)
# in cluster n.2
# Example n.124=(145.0,35.0)
# in cluster n.2
# Example n.125=(146.0,36.0)
# in cluster n.2
# Example n.126=(147.0,37.0)
# in cluster n.2
# Example n.127=(148.0,38.0)
# in cluster n.2
# Example n.128=(149.0,39.0)
# in cluster n.2
# Example n.129=(150.0,40.0)
# in cluster n.2
# Example n.130=(151.0,41.0)
# in cluster n.2
# Example n.131=(152.0,42.0)
# in cluster n.2
# Example n.132=(153.0,43.0)
# in cluster n.2
# Example n.133=(154.0,44.0)
# in cluster n.2
# Example n.134=(155.0,45.0)
# in cluster n.2
# Example n.135=(156.0,46.0)
# in cluster n.2
# Example n.136=(157.0,47.0)
# in cluster n.2
# Example n.137=(158.0,48.0)
# in cluster n.2
# Example n.138=(159.0,49.0)
# in cluster n.2
# Example n.139=(160.0,50.0)
# in cluster n.2
# Example n.140=(161.0,51.0)
# in cluster n.2
# Example n.141=(162.0,52.0)
# in cluster n.2
# Example n.142=(163.0,53.0)
# in cluster n.2
# Example n.143=(164.0,54.0)
# in cluster n.2
# Example n.144=(165.0,55.0)
# in cluster n.2
# Example n.145=(166.0,56.0)
# in cluster n.2
# Example n.146=(167.0,57.0)
# in cluster n.2
# Example n.147=(168.0,58.0)
# in cluster n.2
# Example n.148=(169.0,59.0)
# in cluster n.2
# Example n.149=(170.0,60.0)
# in cluster n.2
# /usr/local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# In the following program we plot the clusters

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8, 8))

ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Clustered points in dataset n. 1")

ax.set_xlabel("x")
ax.set_ylabel("y")

# set the list of colors to be selected when plotting the different clusters
color = ["b", "g", "r", "c", "m", "y", "k", "w"]

# plot the dataset
for clu in range(k):
    # collect the sequence of cooordinates of the points in each given cluster (determined by clu)
    data_list_x = [data1[i, 0] for i in range(n_samples1) if kmeans1.labels_[i] == clu]
    data_list_y = [data1[i, 1] for i in range(n_samples1) if kmeans1.labels_[i] == clu]
    plt.scatter(
        data_list_x, data_list_y, s=2, edgecolors="none", c=color[clu], alpha=0.5
    )

plt.show()

# %% [markdown]
# In the following cell I propose you to perform clustering with K-means on dataset2.

# %%
k = 4
kmeans2 = KMeans(k)
kmeans2.fit(data2)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4)

# %% [markdown]
# In the following you have to plot clustering results on dataset2.
#
# **Answer:**
# how do you explain what happens?

# %%
def plotClusters(dataset, model, k, title):
    fig = plt.figure(figsize=(8, 8))

    ax = fig.add_subplot(111)
    fig.subplots_adjust(top=1)
    ax.set_title(title)

    ax.set_xlabel("x")
    ax.set_ylabel("y")

    # set the list of colors to be selected when plotting the different clusters
    color = ["b", "g", "r", "c", "m", "y", "k", "w"]

    for cluster in range(k):
        clusterx = [
            data[0] for (data, pred) in zip(dataset, model.labels_) if pred == cluster
        ]
        clustery = [
            data[1] for (data, pred) in zip(dataset, model.labels_) if pred == cluster
        ]
        c = color[cluster]
        plt.scatter(clusterx, clustery, c=c)

    # Plot possible noisy points
    clusterx = [data[0] for (data, pred) in zip(dataset, model.labels_) if pred == -1]
    clustery = [data[1] for (data, pred) in zip(dataset, model.labels_) if pred == -1]
    c = "r"
    plt.scatter(clusterx, clustery, c=c, marker="*")

    plt.show()

# %%
plotClusters(data2, kmeans2, k, f"Clustering using kmeans (k = {k}) on dataset 2")

# %% [markdown]
# In the following cell I propose you to perform clustering with K-means on the dataset3.

# %%
k = 5
kmeans3 = KMeans(k)
kmeans3.fit(data3)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5)

# %% [markdown]
# In the following cell, I propose you to plot clustering results on dataset3.
#
# **Answer:**
# how do you explain what happens?

# %%
plotClusters(data3, kmeans3, k, f"Kmeans (K = {k}) performance on dataset 3")

# %% [markdown]
# In the following cells I propose you to write a program that computes with a statistical measure of your choice a quantitative evaluation of clusters in the three datasets.
#
# **Note:**
# It is advisable to execute K-means a certain number of times (let us try 10 times) and then select the clustering solution that gives the best value of the evaluation measure.

# %%
from sklearn.metrics import silhouette_score

k = 5

# USELESS
# retrains = 10
# for dataset in [data1,data2, ]:
# best_model = ""
# best_score = -1
# for i in range(retrains):
# model = KMeans(k , n_init=1)
# model.fit(dataset)
# score= silhouette_score(dataset , model.labels_)
# if score > best_score:
# best_score = score
# best_model = model
# print(f"best_score = {best_score}")
# print(f"best_model = {best_model}")

for dataset in [data1, data2]:
    model = KMeans(k, n_init=10)
    model.fit(dataset)
    print(silhouette_score(dataset, model.labels_))
# Out:
# 0.6372722940289592
# 0.425428785503998

# %% [markdown]
# As already done with classification by k-nn, plot in the cell below the quantitative measure of your choice (used above) with respect to an increasing value of k (the number of clusters) so that the best value of k can be selected.

# %%
silhouettes = []
# Do not put dataset 3 as it takes very long to compute silhouette
for i, dataset in enumerate([data1, data2]):
    silhouettes.append([])
    for k in range(2, 10):
        model = KMeans(k, n_init=15)
        model.fit(dataset)
        score = silhouette_score(dataset, model.labels_)
        silhouettes[i].append(score)

print(silhouettes)
# Out:
# [[0.5651096232579514, 0.7229402453727759, 0.6825234611999134, 0.6372722940289592, 0.6113129278986535, 0.5955877034177369, 0.5802064233248967, 0.56582313863316], [0.43322366812579544, 0.4797378957562134, 0.41677477652119416, 0.42541551752136875, 0.41324317757509255, 0.4336221779907857, 0.44488400345357887, 0.44741666827776566]]

# %%
# Plotting the silhouettes
fig = plt.figure(figsize=(8, 8))

ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("silhouettes at varying values of k")
colors = ["r", "g", "b"]
for i, (scores, color) in enumerate(zip(silhouettes, colors)):
    plt.plot(range(2, 2 + len(scores)), scores, color=color, label=f"data{i+1}")

plt.legend()
plt.show()

# %% [markdown]
# In the following cell I propose you to run DBSCAN, instead, on one of the last two datasets: either dataset2 or dataset3.
#
# At the beginning try using a pair of Minpts and Eps of your choice.
#
# **Note:**
# If the data is too big, **sample it random, using a factor of 0.1.**

# %%
from sklearn.cluster import DBSCAN

dbscan2 = DBSCAN(eps=1.4, min_samples=5)
dbscan2.fit(data2)
# Out:
# DBSCAN(eps=1.4)

# %%
k = len(set(dbscan2.labels_))
plotClusters(
    data2,
    dbscan2,
    k - 1,
    f"Clustering on Dataset 2 done using DBSCAN (k *autocomputed*= {k-1})",
)  # The k - 1 is because dbscan uses also a special -1 value to indicate noisy points
data2_filtered = [x for x, y in zip(data2, dbscan2.labels_) if y != -1]
labels_filtered = [y for y in dbscan2.labels_ if y != -1]
score = silhouette_score(data2_filtered, labels_filtered)
# Come é possibile???
print(f"Silhouette score: {score}")
# Out:
# Silhouette score: -0.2183765056099809

# %% [markdown]
# In the following cell I propose you to:
#
# 1.   Set *Minpts* to a number (say **10**).
# 2.   Compute the **reachability distance** of the **10-th nearest neighbour ** for each data-point.
# 3. Sort the set of reachability distances you obtained in an increasing way.
# 4. Plot the sorted reachability distances
# 5. Find the **elbow** of the diagram => it gives the eps value combined with Minpts=10.
# 6. Try this combined pair of parameters on the dataset you chose, with DBSCAN.

# %%
from sklearn.metrics import DistanceMetric

dist = DistanceMetric.get_metric("euclidean")
minpts = 15
dataset = data2

all_distances = dist.pairwise(dataset, dataset)
result = []
for distances in all_distances:
    d = sorted(distances)
    m_d = d[minpts]
    result.append(m_d)
print(result)
# Out:
# [3.605551275463989, 3.1622776601683795, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.1622776601683795, 3.605551275463989, 3.0, 2.8284271247461903, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.8284271247461903, 3.0, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 4.0, 3.1622776601683795, 3.0, 3.0, 3.0, 3.0, 2.8284271247461903, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.8284271247461903, 3.1622776601683795, 4.0, 3.1622776601683795, 2.8284271247461903, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.8284271247461903, 3.1622776601683795, 2.8284271247461903, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 3.0, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 3.0, 4.0, 3.1622776601683795, 2.8284271247461903, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2.23606797749979, 2 ...

# %%
fig = plt.figure(figsize=(8, 8))

ax = fig.add_subplot(111)
fig.subplots_adjust(top=1)
ax.set_title("Finding The elbow point")

result_sorted = sorted(result)

plt.plot(result_sorted)

plt.show()

# %%
# Using minpts and 2.5 as eps to see how this does
dbscan_opt = DBSCAN(eps=2.5, min_samples=minpts)
dbscan_opt.fit(dataset)

plotClusters(dataset, dbscan_opt, len(set(dbscan_opt.labels_)) - 1, "Final Clustering")
